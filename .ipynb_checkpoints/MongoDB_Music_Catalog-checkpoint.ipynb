# %%
#!pip install musicbrainzngs
#!pip3 install pymongo

# %%
import os
import time
import pprint
import datetime
from pymongo import MongoClient, IndexModel, ASCENDING, DESCENDING
import musicbrainzngs
from musicbrainzngs import *

# %%
# Config musicbrainz
# https://musicbrainz.org/doc/Development/XML_Web_Service/Version_1

musicbrainzngs.set_useragent(app="coffeecode", version=1, contact=None)

# %%
# Connect to MongoDB

client = MongoClient('localhost', 27017)

# %%
# Create db

db = client.jazz_catalog

# %%
# Create three collections
# Note that due to network limitations we will use only a subset of available Musicbrainz metadata

db.drop_collection('artists')
artists = db.artists

db.drop_collection('releases')
releases = db.releases

# %%
# search for an artist

seedArtist = musicbrainzngs.search_artists("miles davis")

# %%
for artist in seedArtist['artist-list']:
    print("{name}, {id}".format(name=artist['name'], id=artist['id']))
# Out:
# Miles Davis, 561d854a-6a28-4aa7-8c99-323e6ce46c2a
# Miles Davis Quintet, fe7245e7-d734-4ca1-8e26-691883f58201
# The Miles Davis Nonet, 16d2b8e6-8930-4c9e-856f-e6d096479350
# Miles Davis Sextet, f137837b-fa55-48d1-8c85-f13961b3ac77
# Miles Davis Quartet, 03606dee-b333-48fe-b9af-d671c837d40f
# Miles Davis Septet, 88130878-7ee9-4ce2-b24b-1dd9da898030
# Miles Davis Moody, d74d6350-a042-4202-b4fd-2a05918a06be
# Miles Davis All Stars, 607d7275-2b92-49e5-a7ee-32f9cc29b076
# Miles Davis + 19, 72f2e1fe-dc92-4011-93d7-2fb6aff4a2bd
# The Miles Davis / Tadd Dameron Quintet, 7103c200-fd5c-4890-8685-5328a055f7ba
# Miles!, f2b73b53-3414-4883-b014-622ab6917215
# Miles Davis and His Orchestra, c52ff92e-b338-4815-bd63-4e9b89795e84
# Miles Davis All Star Sextet, 47c342e2-5c5f-4b5a-b919-8e0ffc329272
# The Shoes Of Miles Davis, addd7107-3955-4461-a62c-0b346feb5450
# Miles Davis & The Modern Jazz Giants, e1b6e38e-ab75-43fc-b994-bfeea9bc7626
# Miles Davis and the Lighthouse All-Stars, 4cd1a02d-9645-4172-8d45-e468e097c23b
# Conrad Roberts, 6f1ce5fe-856a-49ed-b042-09c091d00fc0
# J.R., cab167c8-4c39-44af-a0c4-c32ab86dd680
# Miles, 011249fd-90de-469a-8e6a-605c8bc90828
# Miles, 86b0cc66-a7d7-4f4d-b59f-b897cc15d3bb
# Smiles Davis, 0435916b-88f9-41a6-8919-6ec36845dcc3
# Miles, bfd8a02f-83f6-46ae-89ca-9d21ed2a78c2
# Miles, 7c7b51e4-40b9-416a-aba8-6a7ffe2f111e
# Miles, 28c42c8f-438c-4997-895b-1ef52cf5d9ca
# Robert Miles, e83144dd-bb95-49fe-b1dd-00bab25cca9e

# %%
# Create indexes for mongodb collections
# on ID field, enforce uniqueness constraint

db.artists.create_index('id', name='artist_id', unique=True)
db.releases.create_index('id', name='release_id', unique=True)
# Out:
# 'release_id'

# %%
# Get artist info for top two
# Insert into db.artists

for artist in seedArtist['artist-list'][:2]:
    mbid = artist['id']
    artist_info = musicbrainzngs.get_artist_by_id(mbid)
    pprint.pprint(artist_info)
# Out:
# {'artist': {'area': {'id': '489ce91b-6658-3307-9877-795b68554c98',
#                      'iso-3166-1-code-list': ['US'],
#                      'name': 'United States',
#                      'sort-name': 'United States'},
#             'begin-area': {'id': '39e1719e-2604-4b59-b698-dab7caf85b33',
#                            'name': 'Alton',
#                            'sort-name': 'Alton'},
#             'country': 'US',
#             'disambiguation': 'jazz trumpeter, bandleader, songwriter',
#             'end-area': {'id': 'dbacf2e3-7e3e-4cee-8804-999b109285fa',
#                          'name': 'Santa Monica',
#                          'sort-name': 'Santa Monica'},
#             'gender': 'Male',
#             'id': '561d854a-6a28-4aa7-8c99-323e6ce46c2a',
#             'ipi': '00007619785',
#             'ipi-list': ['00007619785'],
#             'isni-list': ['000000012144707X'],
#             'life-span': {'begin': '1926-05-26',
#                           'end': '1991-09-28',
#                           'ended': 'true'},
#             'name': 'Miles Davis',
#             'sort-name': 'Davis, Miles',
#             'type': 'Person'}}
# {'artist': {'area': {'id': '489ce91b-6658-3307-9877-795b68554c98',
#                      'iso-3166-1-code-list': ['US'],
#                      'name': 'United States',
#                      'sort-name': 'United States'},
#             'begin-area': {'id': '489ce91b-6658-3307-9877-795b68554c98',
#                            'iso-3166-1-code-list': ['US'],
#                            'name': 'United States',
#                            'sort-name': 'United States'},
#             'country': 'US',
#             'disambiguation': 'US jazz group 1955-58, and 1964-68',
#             'end-area': {'id': '489ce91b-6658-3307-9877-795b68554c98',
#                          'iso-3166-1-code-list': ['US'],
#                          'name': 'United States',
#                          'sort-name': 'United States'},
#             'id': 'fe7245e7-d734-4ca1-8e26-691883f58201',
#             'isni-list': ['0000000110083450'],
#             'life-span': {'begin': '1955', 'end': '1968', 'ended': 'true'},
#             'name': 'Miles Davis Quintet',
#             'sort-name': 'Davis, Miles, Quintet',
#             'type': 'Group'}}

# %%
for artist in seedArtist['artist-list'][:2]:
    mbid = artist['id']
    artist_info = musicbrainzngs.get_artist_by_id(mbid)
    artists.insert_one(artist_info['artist'])

# %%
# Try again to check uniqueness constraint

for artist in seedArtist['artist-list'][:2]:
    mbid = artist['id']
    artist_info = musicbrainzngs.get_artist_by_id(mbid)
    try:
        artists.insert_one(artist_info['artist'])
    except Exception as e:
        print(e)
# Out:
# E11000 duplicate key error collection: jazz_catalog.artists index: artist_id dup key: { : "561d854a-6a28-4aa7-8c99-323e6ce46c2a" }
# E11000 duplicate key error collection: jazz_catalog.artists index: artist_id dup key: { : "fe7245e7-d734-4ca1-8e26-691883f58201" }

# %%
db.artists.count()
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: count is deprecated. Use estimated_document_count or count_documents instead. Please note that $where must be replaced by $expr, $near must be replaced by $geoWithin with $center, and $nearSphere must be replaced by $geoWithin with $centerSphere
#   """Entry point for launching an IPython kernel.
# 2

# %%
for a in artists.find():
    pprint.pprint(a)
# Out:
# {'_id': ObjectId('5c086ce6c9efcc1303986738'),
#  'area': {'id': '489ce91b-6658-3307-9877-795b68554c98',
#           'iso-3166-1-code-list': ['US'],
#           'name': 'United States',
#           'sort-name': 'United States'},
#  'begin-area': {'id': '39e1719e-2604-4b59-b698-dab7caf85b33',
#                 'name': 'Alton',
#                 'sort-name': 'Alton'},
#  'country': 'US',
#  'disambiguation': 'jazz trumpeter, bandleader, songwriter',
#  'end-area': {'id': 'dbacf2e3-7e3e-4cee-8804-999b109285fa',
#               'name': 'Santa Monica',
#               'sort-name': 'Santa Monica'},
#  'gender': 'Male',
#  'id': '561d854a-6a28-4aa7-8c99-323e6ce46c2a',
#  'ipi': '00007619785',
#  'ipi-list': ['00007619785'],
#  'isni-list': ['000000012144707X'],
#  'life-span': {'begin': '1926-05-26', 'end': '1991-09-28', 'ended': 'true'},
#  'name': 'Miles Davis',
#  'sort-name': 'Davis, Miles',
#  'type': 'Person'}
# {'_id': ObjectId('5c086ce7c9efcc1303986739'),
#  'area': {'id': '489ce91b-6658-3307-9877-795b68554c98',
#           'iso-3166-1-code-list': ['US'],
#           'name': 'United States',
#           'sort-name': 'United States'},
#  'begin-area': {'id': '489ce91b-6658-3307-9877-795b68554c98',
#                 'iso-3166-1-code-list': ['US'],
#                 'name': 'United States',
#                 'sort-name': 'United States'},
#  'country': 'US',
#  'disambiguation': 'US jazz group 1955-58, and 1964-68',
#  'end-area': {'id': '489ce91b-6658-3307-9877-795b68554c98',
#               'iso-3166-1-code-list': ['US'],
#               'name': 'United States',
#               'sort-name': 'United States'},
#  'id': 'fe7245e7-d734-4ca1-8e26-691883f58201',
#  'isni-list': ['0000000110083450'],
#  'life-span': {'begin': '1955', 'end': '1968', 'ended': 'true'},
#  'name': 'Miles Davis Quintet',
#  'sort-name': 'Davis, Miles, Quintet',
#  'type': 'Group'}

# %%
# Get the first set of releases with 'Official' status
# (keep result sets to default 25 to minimize network impact)
# Make a second call for complete track info and
# Insert response into mongodb releases collection

# ADD BACK 'artist-credits' include

for a in artists.find():
    artist_id = a['id']
    release_search = musicbrainzngs.get_artist_by_id(artist_id, includes=['releases',  'release-rels', 'label-rels'])
    release_list = release_search['artist']['release-list']
    for r in release_list:
        if 'status' in r.keys():
            if r['status'] == "Official":
                release_id = r['id']
                release_info = musicbrainzngs.get_release_by_id(release_id,
                                                                includes=['artist-credits', 'recordings',
                                                                          'recording-level-rels', 'artist-rels'])
                try:
                    releases.insert_one(release_info['release'])
                except Exception as e:
                    print(e)

# %%
db.releases.count()
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: count is deprecated. Use estimated_document_count or count_documents instead. Please note that $where must be replaced by $expr, $near must be replaced by $geoWithin with $center, and $nearSphere must be replaced by $geoWithin with $centerSphere
#   """Entry point for launching an IPython kernel.
# 45

# %%
# so now get all artists info for all tracks on all releases

artist_ids = set()
artist_count = 0

for r in releases.find():
    if 'medium-list' in r:
        media = r['medium-list']
        for m in media:
            if 'track-list' in m:
                tracks = m['track-list']
                for each in tracks:
                    if 'recording' in each.keys():
                        if 'artist-relation-list' in each['recording'].keys():
                            artist_list = each['recording']['artist-relation-list']
                            for a in artist_list:
                                artist_count += 1
                                artist_id = a['artist']['id']
                                artist_ids.add(artist_id)

# %%
artist_count
# Out:
# 1455

# %%
len(artist_ids)
# Out:
# 86

# %%
current_artist_ids = set(artists.distinct('id'))
new_artist_search_ids = artist_ids - current_artist_ids

# %%
len(new_artist_search_ids)
# Out:
# 85

# %%
for a_id in list(new_artist_search_ids):
    artist_info = musicbrainzngs.get_artist_by_id(a_id)
    try:
        artists.insert_one(artist_info['artist'])
    except Exception as e:
        print(e)

# %%
artists.count()
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: count is deprecated. Use estimated_document_count or count_documents instead. Please note that $where must be replaced by $expr, $near must be replaced by $geoWithin with $center, and $nearSphere must be replaced by $geoWithin with $centerSphere
#   """Entry point for launching an IPython kernel.
# 87

# %%
# now redo release search for all new artists - there may be some duplicates

# Get the first set of releases with 'Official' status
# (keep result sets to default 25 to minimize network impact)
# Make a second call for complete track info and
# Insert response into mongodb releases collection

for a_id in list(new_artist_search_ids):
    release_search = musicbrainzngs.get_artist_by_id(a_id, includes=['releases',  'release-rels', 'label-rels'])
    release_list = release_search['artist']['release-list']
    for r in release_list:
        if 'status' in r.keys():
            if r['status'] == "Official":
                release_id = r['id']
                release_info = musicbrainzngs.get_release_by_id(release_id,
                                                                includes=['artist-credits', 'recordings', 
                                                                          'recording-level-rels', 'artist-rels'])
                try:
                    releases.insert_one(release_info['release'])
                except Exception as e:
                    print(e)
# Out:
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "09d238f8-22b0-4d52-aa73-958f393dfab9" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "9158c339-0fc5-46aa-958b-8db2bc0f5c79" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "2c6f3c86-0df2-4033-b709-4b4dbaacc120" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "38bdd071-9f00-41f9-9b90-ea4548f10225" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "1198ed14-429d-4c0e-b1af-152d54046343" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "ed3b8786-015c-4880-b32a-1acf1c639ed3" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "f330c2c9-ea2b-4a56-9b16-68124480f9e8" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "8105b68f-e30b-4c12-9ed9-4e5d38008dc0" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "a86aaf57-8582-4b9c-ab64-a5e098618646" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "f330c2c9-ea2b-4a56-9b16-68124480f9e8" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "e794c112-3745-458f-b912-d225e5008f51" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "09d238f8-22b0-4d52-aa73-958f393dfab9" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "0bc26986-223f-447b-bef9-8655f949fa5f" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "1198ed14-429d-4c0e-b1af-152d54046343" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "784ee064-d26f-4b51-8821-00b40c410f82" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "8b6162f0-2876-44b2-842c-9b2fe9761e20" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "9158c339-0fc5-46aa-958b-8db2bc0f5c79" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "aa8b6539-66a2-432a-981a-065fd44c91e7" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "b22a6996-f501-4c28-a967-fa69472523c6" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "bf31f2c3-e26c-46a0-9636-e4cd04f0ce6a" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "e479f4ef-b6c3-4333-8808-37e3515a4ce8" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "ecf29a5d-8ed2-44de-a8dd-8d1fffb2d263" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "a86aaf57-8582-4b9c-ab64-a5e098618646" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "e794c112-3745-458f-b912-d225e5008f51" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "3de69ac9-adcb-4d46-a8d8-8cd19b365c23" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "50cbb6f6-206e-4be4-9d8f-419d8889ab5d" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "5ba7d9cd-e3c5-45c6-a924-1c4c31000b4f" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "85262298-e9bf-4522-b10b-3f87bb352a93" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "2c6f3c86-0df2-4033-b709-4b4dbaacc120" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "72478b97-72a1-417a-b7b1-7128bf9ec5bc" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "78262678-70a7-495d-90b3-255c5b5ccf54" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "b76b6bfa-0710-47fa-8d99-e015512f7ce8" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "a74521f3-4ff8-4ef1-9e38-90e64dc730c4" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "148b4b37-a990-4e26-9f97-f8f90023005d" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "27fa6c63-1733-4714-9f1e-fb8b91a3f780" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "2c6f3c86-0df2-4033-b709-4b4dbaacc120" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "72478b97-72a1-417a-b7b1-7128bf9ec5bc" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "85105582-8de2-403b-af98-1441e2ece73f" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "9890d3c1-8275-4887-af5c-250a4a1ed311" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "08a8d7dc-6531-4c56-a71e-2ed9f18e8b94" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "368d111b-727c-39d5-8108-2b2ff63527ae" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "3ac42028-5c66-436a-9f23-392f28fe8993" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "543005e6-67a4-4bc5-a6e0-17f639297759" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "762c2f94-e354-4ec3-b2d3-d0492f0b3c32" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "7a6f2dd0-28a6-4299-8f8d-7aaca1d2f5bf" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "9715b0ac-a65e-4494-868c-1d87f1caf049" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "eea105ea-0652-4c04-87c7-f56677c45ad0" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "f8239dcf-a9d5-4a65-ac69-5dcd68fba746" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "09d238f8-22b0-4d52-aa73-958f393dfab9" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "48704cf6-8176-490e-8ec1-fd0fd413ca2a" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "5bf19e82-0df4-47e4-a602-5c5e9f4b6757" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "9158c339-0fc5-46aa-958b-8db2bc0f5c79" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "aa8b6539-66a2-432a-981a-065fd44c91e7" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "be7ad28d-a77b-4756-ba3d-48ce2c612bd9" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "ecf29a5d-8ed2-44de-a8dd-8d1fffb2d263" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "c0455189-a052-4aa6-9555-25c812e8fc3a" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "78262678-70a7-495d-90b3-255c5b5ccf54" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "b89b5aa8-b41f-4e96-b1e4-92a49a28ad17" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "45ca3307-42e9-48b6-95d9-03ba1d26a3cf" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "a8187d05-a024-427e-b82c-323145837282" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "56ec70d0-012f-47cc-8b86-a10a5e54a06b" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "cd3df116-7a29-47d7-94de-5eca2876a9b1" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "385cdb46-8645-425d-a37a-4c62553d0820" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "45ca3307-42e9-48b6-95d9-03ba1d26a3cf" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "70d4f763-3703-49eb-bc86-5a5b9185fafc" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "a3822098-f941-4672-bfe1-e4c916224548" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "b8c24108-8db1-3050-af03-875b920f01c6" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "3aef34c7-0773-49d6-ba4f-9c3269b81ef6" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "4114b581-7f9f-45f1-b83f-45bab0ac3ebe" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "b5a225d6-c977-4090-af34-02c7bab87d70" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "cd3df116-7a29-47d7-94de-5eca2876a9b1" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "d5b9e2b6-7887-48c8-a076-d917de625f8d" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "e479f4ef-b6c3-4333-8808-37e3515a4ce8" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "2c6f3c86-0df2-4033-b709-4b4dbaacc120" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "5cf64d06-a221-46d0-9756-1cb8266e4a47" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "0c0a5b7e-3e18-438b-a711-58a6302ba876" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "814be108-b3cb-3aec-9dea-a7fbafa89255" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "f100e4a3-8864-4187-b291-134137941345" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "f247c510-83e7-4851-8ec1-8664a97fd605" }
# E11000 duplicate key error collection: jazz_catalog.releases index: release_id dup key: { : "dd7074b9-8283-4d0f-8c32-8af7910ceb36" }

# %%
db.releases.count()
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: count is deprecated. Use estimated_document_count or count_documents instead. Please note that $where must be replaced by $expr, $near must be replaced by $geoWithin with $center, and $nearSphere must be replaced by $geoWithin with $centerSphere
#   """Entry point for launching an IPython kernel.
# 889

# %%
a_release = releases.find_one()

# %%
pprint.pprint(a_release)
# Out:
# {'_id': ObjectId('5c086cebc9efcc130398673c'),
#  'artist-credit': [{'artist': {'disambiguation': 'jazz trumpeter, bandleader, '
#                                                  'songwriter',
#                                'id': '561d854a-6a28-4aa7-8c99-323e6ce46c2a',
#                                'name': 'Miles Davis',
#                                'sort-name': 'Davis, Miles'}}],
#  'artist-credit-phrase': 'Miles Davis',
#  'country': 'US',
#  'cover-art-archive': {'artwork': 'true',
#                        'back': 'false',
#                        'count': '1',
#                        'front': 'true'},
#  'date': '1954',
#  'id': '16ed7b47-e00c-499d-8866-65e660f4c78f',
#  'medium-count': 1,
#  'medium-list': [{'format': '12" Vinyl',
#                   'position': '1',
#                   'track-count': 6,
#                   'track-list': [{'artist-credit': [{'artist': {'disambiguation': 'jazz '
#                                                                                   'trumpeter, '
#                                                                                   'bandleader, '
#                                                                                   'songwriter',
#                                                                 'id': '561d854a-6a28-4aa7-8c99-323e6ce46c2a',
#                                                                 'name': 'Miles '
#                                                                         'Davis',
#                                                                 'sort-name': 'Davis, '
#                                                                              'Miles'}}],
#                                   'artist-credit-phrase': 'Miles Davis',
#                                   'id': '37e8f384-fd8f-3980-ab99-c69271a21204',
#                                   'length': '220360',
#                                   'number': '1',
#                                   'position': '1',
#                                   'recording': {'artist-credit': [{'artist': {'disambiguation': 'jazz '
#                                                                                                 'trumpeter, '
#                                                                                                 'bandleader, '
#                                                                                                 'songwriter',
#                                                                               'id': '561d854a-6a28-4aa7-8c99-323e6ce46c2a',
#                                                                               'name': 'Miles '
#                                                                                       'Davis',
#                                                                               'sort-name': 'Davis, '
#                                                                                            'Miles'}}],
#                                                 'artist-credit-phrase': 'Miles '
#                                                                         'Davis',
#                                                 'artist-relation-list': [{'artist': {'id': '534362cd-66ed-45a8-9cba-b847dbf75b6f',
#                                                                                      'name': 'Percy '
#                                                                                              'Heath',
#                                                                                      'sort-name': 'Heath, '
#                                                                                                   'Percy'},
#                                                                           'attribute-list': ['bass'],
#                                                                           'attributes': [{'attribute': 'bass'}],
#                                                                           'begin': '1954-03-06',
#                                                                           'direction': 'backward',
#                                                                           'end': '1954-03-06',
#                                                                           'ended': 'true',
#                                                                           'target': '534362cd-66ed-45a8-9cba-b847dbf75b6f',
#                                                                           'type': 'instrument',
#                                                                           'type-id': '59054b12-01ac-43ee-a618-285fd397e461'},
#                                                                          {'artist': {'disambiguation': 'jazz '
#                                                                                                        'trumpeter, '
#                                                                                                        'bandleader, '
#                                                                                                        'songwriter',
#                                                                                      'id': '561d854a-6a28-4aa7-8c99-323e6ce46c2a',
#                                                                                      'name': 'Miles '
#                                                                                              'Davis',
#                                                                                      'sort-name': 'Davis, '
#                                                                                                   'Miles'},
#                                                                           'attribute-list': ['trumpet'],
#                                                                           'attributes': [{'attribute': 'trumpet'}],
#                                                                           'begin': '1954-03-06',
#                                                                           'direction': 'backward',
#                                                                           'end': '1954-03-06',
#                                                                           'ended': 'true',
#                                                                           'target': '561d854a-6a28-4aa7-8c99-323e6ce46c2a',
#                                                                           'type': 'instrument',
#                                                                           'type-id': '59054b12-01ac-43ee-a618-285fd397e461'},
#                                                                          {'artist': {'id': '601e7466-eaf5-4a91-9909-ffd770b7e04a',
#                                                                                      'name': 'Art '
#                                                                                              'Blakey',
#                                                                                      'sort-name': 'Blakey, '
#                                                                                                   'Art'},
#                                                                           'attribute-list': ['drums '
#                                                                                              '(drum '
#                                                                                              'set)'],
#                                                                           'attributes': [{'attribute': 'drums '
#                                                                                                        '(drum '
#                                                                                                        'set)'}],
#                                                                           'begin': '1954-03-06',
#                                                                           'direction': 'backward',
#                                                                           'end': '1954-03-06',
#                                                                           'ended': 'true',
#                                                                           'target': '601e7466-eaf5-4a91-9909-ffd770b7e04a',
#                                                                           'type': 'instrument',
#                                                                           'type-id': '59054b12-01ac-43ee-a618-285fd397e461'},
#                                                                          {'artist': {'id': 'c332fcf2-cc5c-424e-a5ea-317b31f6c035',
#                                                                                      'name': 'Alfred '
#                                                                                              'Lion',
#                                                                                      'sort-name': 'Lion, '
#                                                                                                   'Alfred'},
#                                                                           'direction': 'backward',
#                                                                           'target': 'c332fcf2-cc5c-424e-a5ea-317b31f6c035',
#                                                                           'type': 'producer',
#                                                                           'type-id': '5c0ceac3-feb4-41f0-868d-dc06f6e27fc0'},
#                                                                          {'artist': {'id': 'd185d986-ee96-4fd3-bd61-8c848a4765b6',
#                                                                                      'name': 'Horace '
#                                                                                              'Silver',
#                                                                                      'sort-name': 'Silver, '
#                                                                                                   'Horace'},
#                                                                           'attribute-list': ['piano'],
#                                                                           'attributes': [{'attribute': 'piano'}],
#                                                                           'begin': '1954-03-06',
#                                                                           'direction': 'backward',
#                                                                           'end': '1954-03-06',
#                                                                           'ended': 'true',
#                                                                           'target': 'd185d986-ee96-4fd3-bd61-8c848a4765b6',
#                                                                           'type': 'instrument',
#                                                                           'type-id': '59054b12-01ac-43ee-a618-285fd397e461'}],
#                                                 'id': 'd94bc993-7d18-4bb9-a95e-a1eb2ed309d4',
#                                                 'length': '220360',
#                                                 'title': 'Take Off'},
#                                   'track_or_recording_length': '220360'},
#                                  {'artist-credit': [{'artist': {'disambiguation': 'jazz '
#                                                                                   'trumpeter, '
#                                                                                   'bandleader, '
#                                                                                   'songwriter',
#                                                                 'id': '561d854a-6a28-4aa7-8c99-323e6ce46c2a',
#                                                                 'name': 'Miles '
#                                                                         'Davis',
#                                                                 'sort-name': 'Davis, '
#                                                                              'Miles'}}],
#                                   'artist-credit-phrase': 'Miles Davis',
#                                   'id': '60fa3292-611c-319a-9d6b-b9d97c6e1249',
#                                   'length': '242760',
#                                   'number': '2',
#                                   'position': '2',
#                                   'recording': {'artist-credit': [{'artist': {'disambiguation': 'jazz '
#                                                                                                 'trumpeter, '
#                                                                                                 'bandleader, '
#                                                                                                 'songwriter',
#                                                                               'id': '561d854a-6a28-4aa7-8c99-323e6ce46c2a',
#                                                                               'name': 'Miles '
#                                                                                       'Davis',
#                                                                               'sort-name': 'Davis, '
#                                                                                            'Miles'}}],
#                                                 'artist-credit-phrase': 'Miles '
#                                                                         'Davis',
#                                                 'id': '83142edc-1c9d-41e5-9580-78c88ae74f6a',
#                                                 'length': '242760',
#                                                 'title': 'It Never Entered My '
#                                                          'Mind'},
#                                   'track_or_recording_length': '242760'},
#                                  {'artist-credit': [{'artist': {'disambiguation': 'jazz '
#                                                                                   'trumpeter, '
#                                                                                   'bandleader, '
#                                                                                   'songwriter',
#                                                                 'id': '561d854a-6a28-4aa7-8c99-323e6ce46c2a',
#                                                                 'name': 'Miles '
#                                                                         'Davis',
#                                                                 'sort-name': 'Davis, '
#                                                                              'Miles'}}],
#                                   'artist-credit-phrase': 'Miles Davis',
#                                   'id': 'eb18e59b-95f1-3812-bdf9-5b654ec95008',
#                                   'length': '322560',
#                                   'number': '3',
#                                   'position': '3',
#                                   'recording': {'artist-credit': [{'artist': {'disambiguation': 'jazz '
#                                                                                                 'trumpeter, '
#                                                                                                 'bandleader, '
#                                                                                                 'songwriter',
#                                                                               'id': '561d854a-6a28-4aa7-8c99-323e6ce46c2a',
#                                                                               'name': 'Miles '
#                                                                                       'Davis',
#                                                                               'sort-name': 'Davis, '
#                                                                                            'Miles'}}],
#                                                 'artist-credit-phrase': 'Miles '
#                                                                         'Davis',
#                                                 'id': 'b197e54d-69e7-4e25-aefe-fb3d5cbdb0d9',
#                                                 'length': '322560',
#                                                 'title': "Well You Needn't"},
#                                   'track_or_recording_length': '322560'},
#                                  {'artist-credit': [{'artist': {'disambiguation': 'jazz '
#                                                                                   'trumpeter, '
#                                                                                   'bandleader, '
#                                                                                   'songwriter',
#                                                                 'id': '561d854a-6a28-4aa7-8c99-323e6ce46c2a',
#                                                                 'name': 'Miles '
#                                                                         'Davis',
#                                                                 'sort-name': 'Davis, '
#                                                                              'Miles'}}],
#                                   'artist-credit-phrase': 'Miles Davis',
#                                   'id': '3727b327-f283-38d8-8d01-cd3ab449b9eb',
#                                   'length': '242453',
#                                   'number': '4',
#                                   'position': '4',
#                                   'recording': {'artist-credit': [{'artist': {'disambiguation': 'jazz '
#                                                                                                 'trumpeter, '
#                                                                                                 'bandleader, '
#                                                                                                 'songwriter',
#                                                                               'id': '561d854a-6a28-4aa7-8c99-323e6ce46c2a',
#                                                                               'name': 'Miles '
#                                                                                       'Davis',
#                                                                               'sort-name': 'Davis, '
#                                                                                            'Miles'}}],
#                                                 'artist-credit-phrase': 'Miles '
#                                                                         'Davis',
#                                                 'artist-relation-list': [{'artist': {'id': '534362cd-66ed-45a8-9cba-b847dbf75b6f',
#                                                                                      'name': 'Percy '
#                                                                                              'Heath',
#                                                                                      'sort-name': 'Heath, '
#                                                                                                   'Percy'},
#                                                                           'attribute-list': ['bass'],
#                                                                           'attributes': [{'attribute': 'bass'}],
#                                                                           'begin': '1954-03-06',
#                                                                           'direction': 'backward',
#                                                                           'end': '1954-03-06',
#                                                                           'ended': 'true',
#                                                                           'target': '534362cd-66ed-45a8-9cba-b847dbf75b6f',
#                                                                           'type': 'instrument',
#                                                                           'type-id': '59054b12-01ac-43ee-a618-285fd397e461'},
#                                                                          {'artist': {'disambiguation': 'jazz '
#                                                                                                        'trumpeter, '
#                                                                                                        'bandleader, '
#                                                                                                        'songwriter',
#                                                                                      'id': '561d854a-6a28-4aa7-8c99-323e6ce46c2a',
#                                                                                      'name': 'Miles '
#                                                                                              'Davis',
#                                                                                      'sort-name': 'Davis, '
#                                                                                                   'Miles'},
#                                                                           'attribute-list': ['trumpet'],
#                                                                           'attributes': [{'attribute': 'trumpet'}],
#                                                                           'begin': '1954-03-06',
#                                                                           'direction': 'backward',
#                                                                           'end': '1954-03-06',
#                                                                           'ended': 'true',
#                                                                           'target': '561d854a-6a28-4aa7-8c99-323e6ce46c2a',
#                                                                           'type': 'instrument',
#                                                                           'type-id': '59054b12-01ac-43ee-a618-285fd397e461'},
#                                                                          {'artist': {'id': '601e7466-eaf5-4a91-9909-ffd770b7e04a',
#                                                                                      'name': 'Art '
#                                                                                              'Blakey',
#                                                                                      'sort-name': 'Blakey, '
#                                                                                                   'Art'},
#                                                                           'attribute-list': ['drums '
#                                                                                              '(drum '
#                                                                                              'set)'],
#                                                                           'attributes': [{'attribute': 'drums '
#                                                                                                        '(drum '
#                                                                                                        'set)'}],
#                                                                           'begin': '1954-03-06',
#                                                                           'direction': 'backward',
#                                                                           'end': '1954-03-06',
#                                                                           'ended': 'true',
#                                                                           'target': '601e7466-eaf5-4a91-9909-ffd770b7e04a',
#                                                                           'type': 'instrument',
#                                                                           'type-id': '59054b12-01ac-43ee-a618-285fd397e461'},
#                                                                          {'artist': {'id': 'c332fcf2-cc5c-424e-a5ea-317b31f6c035',
#                                                                                      'name': 'Alfred '
#                                                                                              'Lion',
#                                                                                      'sort-name': 'Lion, '
#                                                                                                   'Alfred'},
#                                                                           'direction': 'backward',
#                                                                           'target': 'c332fcf2-cc5c-424e-a5ea-317b31f6c035',
#                                                                           'type': 'producer',
#                                                                           'type-id': '5c0ceac3-feb4-41f0-868d-dc06f6e27fc0'},
#                                                                          {'artist': {'id': 'd185d986-ee96-4fd3-bd61-8c848a4765b6',
#                                                                                      'name': 'Horace '
#                                                                                              'Silver',
#                                                                                      'sort-name': 'Silver, '
#                                                                                                   'Horace'},
#                                                                           'attribute-list': ['piano'],
#                                                                           'attributes': [{'attribute': 'piano'}],
#                                                                           'begin': '1954-03-06',
#                                                                           'direction': 'backward',
#                                                                           'end': '1954-03-06',
#                                                                           'ended': 'true',
#                                                                           'target': 'd185d986-ee96-4fd3-bd61-8c848a4765b6',
#                                                                           'type': 'instrument',
#                                                                           'type-id': '59054b12-01ac-43ee-a618-285fd397e461'}],
#                                                 'id': 'b9faced3-002b-4362-bad9-fcae9d962650',
#                                                 'length': '242453',
#                                                 'title': 'Lazy Susan'},
#                                   'track_or_recording_length': '242453'},
#                                  {'artist-credit': [{'artist': {'disambiguation': 'jazz '
#                                                                                   'trumpeter, '
#                                                                                   'bandleader, '
#                                                                                   'songwriter',
#                                                                 'id': '561d854a-6a28-4aa7-8c99-323e6ce46c2a',
#                                                                 'name': 'Miles '
#                                                                         'Davis',
#                                                                 'sort-name': 'Davis, '
#                                                                              'Miles'}}],
#                                   'artist-credit-phrase': 'Miles Davis',
#                                   'id': 'b847dd8f-d97d-3507-86b3-c3ff09ef9b0a',
#                                   'length': '284533',
#                                   'number': '5',
#                                   'position': '5',
#                                   'recording': {'artist-credit': [{'artist': {'disambiguation': 'jazz '
#                                                                                                 'trumpeter, '
#                                                                                                 'bandleader, '
#                                                                                                 'songwriter',
#                                                                               'id': '561d854a-6a28-4aa7-8c99-323e6ce46c2a',
#                                                                               'name': 'Miles '
#                                                                                       'Davis',
#                                                                               'sort-name': 'Davis, '
#                                                                                            'Miles'}}],
#                                                 'artist-credit-phrase': 'Miles '
#                                                                         'Davis',
#                                                 'artist-relation-list': [{'artist': {'id': '534362cd-66ed-45a8-9cba-b847dbf75b6f',
#                                                                                      'name': 'Percy '
#                                                                                              'Heath',
#                                                                                      'sort-name': 'Heath, '
#                                                                                                   'Percy'},
#                                                                           'attribute-list': ['bass'],
#                                                                           'attributes': [{'attribute': 'bass'}],
#                                                                           'begin': '1954-03-06',
#                                                                           'direction': 'backward',
#                                                                           'end': '1954-03-06',
#                                                                           'ended': 'true',
#                                                                           'target': '534362cd-66ed-45a8-9cba-b847dbf75b6f',
#                                                                           'type': 'instrument',
#                                                                           'type-id': '59054b12-01ac-43ee-a618-285fd397e461'},
#                                                                          {'artist': {'disambiguation': 'jazz '
#                                                                                                        'trumpeter, '
#                                                                                                        'bandleader, '
#                                                                                                        'songwriter',
#                                                                                      'id': '561d854a-6a28-4aa7-8c99-323e6ce46c2a',
#                                                                                      'name': 'Miles '
#                                                                                              'Davis',
#                                                                                      'sort-name': 'Davis, '
#                                                                                                   'Miles'},
#                                                                           'attribute-list': ['trumpet'],
#                                                                           'attributes': [{'attribute': 'trumpet'}],
#                                                                           'begin': '1954-03-06',
#                                                                           'direction': 'backward',
#                                                                           'end': '1954-03-06',
#                                                                           'ended': 'true',
#                                                                           'target': '561d854a-6a28-4aa7-8c99-323e6ce46c2a',
#                                                                           'type': 'instrument',
#                                                                           'type-id': '59054b12-01ac-43ee-a618-285fd397e461'},
#                                                                          {'artist': {'id': '601e7466-eaf5-4a91-9909-ffd770b7e04a',
#                                                                                      'name': 'Art '
#                                                                                              'Blakey',
#                                                                                      'sort-name': 'Blakey, '
#                                                                                                   'Art'},
#                                                                           'attribute-list': ['drums '
#                                                                                              '(drum '
#                                                                                              'set)'],
#                                                                           'attributes': [{'attribute': 'drums '
#                                                                                                        '(drum '
#                                                                                                        'set)'}],
#                                                                           'begin': '1954-03-06',
#                                                                           'direction': 'backward',
#                                                                           'end': '1954-03-06',
#                                                                           'ended': 'true',
#                                                                           'target': '601e7466-eaf5-4a91-9909-ffd770b7e04a',
#                                                                           'type': 'instrument',
#                                                                           'type-id': '59054b12-01ac-43ee-a618-285fd397e461'},
#                                                                          {'artist': {'id': 'c332fcf2-cc5c-424e-a5ea-317b31f6c035',
#                                                                                      'name': 'Alfred '
#                                                                                              'Lion',
#                                                                                      'sort-name': 'Lion, '
#                                                                                                   'Alfred'},
#                                                                           'direction': 'backward',
#                                                                           'target': 'c332fcf2-cc5c-424e-a5ea-317b31f6c035',
#                                                                           'type': 'producer',
#                                                                           'type-id': '5c0ceac3-feb4-41f0-868d-dc06f6e27fc0'},
#                                                                          {'artist': {'id': 'd185d986-ee96-4fd3-bd61-8c848a4765b6',
#                                                                                      'name': 'Horace '
#                                                                                              'Silver',
#                                                                                      'sort-name': 'Silver, '
#                                                                                                   'Horace'},
#                                                                           'attribute-list': ['piano'],
#                                                                           'attributes': [{'attribute': 'piano'}],
#                                                                           'begin': '1954-03-06',
#                                                                           'direction': 'backward',
#                                                                           'end': '1954-03-06',
#                                                                           'ended': 'true',
#                                                                           'target': 'd185d986-ee96-4fd3-bd61-8c848a4765b6',
#                                                                           'type': 'instrument',
#                                                                           'type-id': '59054b12-01ac-43ee-a618-285fd397e461'}],
#                                                 'id': '7712a88c-b965-4780-85fb-029ceb19e203',
#                                                 'length': '284866',
#                                                 'title': 'Weirdo'},
#                                   'track_or_recording_length': '284533'},
#                                  {'artist-credit': [{'artist': {'disambiguation': 'jazz '
#                                                                                   'trumpeter, '
#                                                                                   'bandleader, '
#                                                                                   'songwriter',
#                                                                 'id': '561d854a-6a28-4aa7-8c99-323e6ce46c2a',
#                                                                 'name': 'Miles '
#                                                                         'Davis',
#                                                                 'sort-name': 'Davis, '
#                                                                              'Miles'}}],
#                                   'artist-credit-phrase': 'Miles Davis',
#                                   'id': '3e21410e-342c-31dc-b0eb-f12c677f9743',
#                                   'length': '270880',
#                                   'number': '6',
#                                   'position': '6',
#                                   'recording': {'artist-credit': [{'artist': {'disambiguation': 'jazz '
#                                                                                                 'trumpeter, '
#                                                                                                 'bandleader, '
#                                                                                                 'songwriter',
#                                                                               'id': '561d854a-6a28-4aa7-8c99-323e6ce46c2a',
#                                                                               'name': 'Miles '
#                                                                                       'Davis',
#                                                                               'sort-name': 'Davis, '
#                                                                                            'Miles'}}],
#                                                 'artist-credit-phrase': 'Miles '
#                                                                         'Davis',
#                                                 'id': '601507c2-eef3-4d2c-a07f-9ef254f2a1fd',
#                                                 'length': '271000',
#                                                 'title': 'The Leap'},
#                                   'track_or_recording_length': '270880'}]}],
#  'packaging': 'Cardboard/Paper Sleeve',
#  'quality': 'normal',
#  'release-event-count': 1,
#  'release-event-list': [{'area': {'id': '489ce91b-6658-3307-9877-795b68554c98',
#                                   'iso-3166-1-code-list': ['US'],
#                                   'name': 'United States',
#                                   'sort-name': 'United States'},
#                          'date': '1954'}],
#  'status': 'Official',
#  'text-representation': {'language': 'eng', 'script': 'Latn'},
#  'title': 'Miles Davis, Volume 3'}

# %%
artist_ids = set()
artist_count = 0

for r in releases.find():
    if 'medium-list' in r:
        media = r['medium-list']
        for m in media:
            if 'track-list' in m:
                tracks = m['track-list']
                for each in tracks:
                    if 'recording' in each.keys():
                        if 'artist-relation-list' in each['recording'].keys():
                            artist_list = each['recording']['artist-relation-list']
                            for a in artist_list:
                                artist_count += 1
                                artist_id = a['artist']['id']
                                artist_ids.add(artist_id)

# %%
artist_count
# Out:
# 34314

# %%
len(artist_ids)
# Out:
# 1503

# %%
current_artist_ids = set(artists.distinct('id'))
new_artist_search_ids = artist_ids - current_artist_ids

# %%
len(new_artist_search_ids)
# Out:
# 1417

# %%
for a_id in list(new_artist_search_ids):
    artist_info = musicbrainzngs.get_artist_by_id(a_id)
    try:
        artists.insert_one(artist_info['artist'])
    except Exception as e:
        print(e)

# %%
artists.count()
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: count is deprecated. Use estimated_document_count or count_documents instead. Please note that $where must be replaced by $expr, $near must be replaced by $geoWithin with $center, and $nearSphere must be replaced by $geoWithin with $centerSphere
#   """Entry point for launching an IPython kernel.
# 1504

# %%
releases.count()
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:1: DeprecationWarning: count is deprecated. Use estimated_document_count or count_documents instead. Please note that $where must be replaced by $expr, $near must be replaced by $geoWithin with $center, and $nearSphere must be replaced by $geoWithin with $centerSphere
#   """Entry point for launching an IPython kernel.
# 889

# %% [markdown]
# ## Aggregations

# %%
# https://info-mongodb-com.s3.amazonaws.com/ReferenceCards15-PDF.pdf

# pseduo-SQL
'''
SELECT type, count(type)
FROM artists
GROUP BY type
'''

pipeline = [{"$group": {"_id": "$type", "count":{"$sum":1}}}]
artist_types = list(artists.aggregate(pipeline, allowDiskUse=True))
artist_types
# Out:
# [{'_id': 'Person', 'count': 1454},
#  {'_id': 'Group', 'count': 25},
#  {'_id': 'Orchestra', 'count': 7},
#  {'_id': None, 'count': 17},
#  {'_id': 'Other', 'count': 1}]

# %%
# pseudo-SQL
# requires an artist table and a birthplace table

'''
SELECT begin-area.name, count(begin-area.name), artist.begin-area-id
FROM begin-area
INNER JOIN artist ON begin-area.id == artist.begin-area-id
GROUP BY begin-area
'''

pipeline = [{"$group": {"_id": "$begin-area.name", "count":{"$sum":1}}},
           {"$sort": {"count":-1}}]
artist_birthplaces = list(artists.aggregate(pipeline, allowDiskUse=True))
artist_birthplaces
# Out:
# [{'_id': None, 'count': 640},
#  {'_id': 'New York', 'count': 89},
#  {'_id': 'Philadelphia', 'count': 48},
#  {'_id': 'Chicago', 'count': 29},
#  {'_id': 'Brooklyn', 'count': 27},
#  {'_id': 'Los Angeles', 'count': 24},
#  {'_id': 'Detroit', 'count': 22},
#  {'_id': 'Pittsburgh', 'count': 20},
#  {'_id': 'Kansas City', 'count': 12},
#  {'_id': 'St. Louis', 'count': 11},
#  {'_id': 'Newark', 'count': 11},
#  {'_id': 'Boston', 'count': 11},
#  {'_id': 'New Orleans', 'count': 9},
#  {'_id': 'Memphis', 'count': 8},
#  {'_id': 'Washington, D.C.', 'count': 8},
#  {'_id': 'Oakland', 'count': 7},
#  {'_id': 'Harlem', 'count': 7},
#  {'_id': 'Dallas', 'count': 7},
#  {'_id': 'Indianapolis', 'count': 7},
#  {'_id': 'Cleveland', 'count': 7},
#  {'_id': 'Cincinnati', 'count': 6},
#  {'_id': 'Buffalo', 'count': 5},
#  {'_id': 'Baltimore', 'count': 5},
#  {'_id': 'Manhattan', 'count': 4},
#  {'_id': 'Montreal', 'count': 4},
#  {'_id': 'United States', 'count': 4},
#  {'_id': 'Rio de Janeiro', 'count': 4},
#  {'_id': 'Tampa', 'count': 4},
#  {'_id': 'Berlin', 'count': 4},
#  {'_id': 'San Francisco', 'count': 4},
#  {'_id': 'Virginia', 'count': 4},
#  {'_id': 'Toledo', 'count': 4},
#  {'_id': 'Houston', 'count': 4},
#  {'_id': 'Columbus', 'count': 4},
#  {'_id': 'Charleston', 'count': 4},
#  {'_id': 'London', 'count': 4},
#  {'_id': 'Atlantic City', 'count': 4},
#  {'_id': 'Paris', 'count': 3},
#  {'_id': 'Tulsa', 'count': 3},
#  {'_id': 'Birmingham', 'count': 3},
#  {'_id': 'Columbia', 'count': 3},
#  {'_id': 'Tokyo', 'count': 3},
#  {'_id': 'Copenhagen', 'count': 3},
#  {'_id': 'Miami', 'count': 3},
#  {'_id': 'Queens', 'count': 3},
#  {'_id': 'Jersey City', 'count': 3},
#  {'_id': 'New Jersey', 'count': 3},
#  {'_id': 'Yonkers', 'count': 3},
#  {'_id': 'Savannah', 'count': 3},
#  {'_id': 'Toronto', 'count': 3},
#  {'_id': 'North Carolina', 'count': 3},
#  {'_id': 'Stockholm', 'count': 3},
#  {'_id': 'Oklahoma City', 'count': 3},
#  {'_id': 'Minneapolis', 'count': 3},
#  {'_id': 'Hilversum', 'count': 3},
#  {'_id': 'Camden', 'count': 3},
#  {'_id': 'Dayton', 'count': 3},
#  {'_id': 'Richmond', 'count': 3},
#  {'_id': 'Atlanta', 'count': 3},
#  {'_id': 'Springfield', 'count': 3},
#  {'_id': 'Milwaukee', 'count': 3},
#  {'_id': 'La Habana', 'count': 3},
#  {'_id': 'Monroe', 'count': 2},
#  {'_id': 'Urbana', 'count': 2},
#  {'_id': 'Praha', 'count': 2},
#  {'_id': 'Oslo', 'count': 2},
#  {'_id': 'Huntington', 'count': 2},
#  {'_id': 'Akron', 'count': 2},
#  {'_id': 'Evanston', 'count': 2},
#  {'_id': 'Cologne', 'count': 2},
#  {'_id': 'Danville', 'count': 2},
#  {'_id': 'Wien', 'count': 2},
#  {'_id': 'Wilmington', 'count': 2},
#  {'_id': 'Mishawaka', 'count': 2},
#  {'_id': 'Jacksonville', 'count': 2},
#  {'_id': 'San Juan', 'count': 2},
#  {'_id': 'Mississippi', 'count': 2},
#  {'_id': 'Pennsylvania', 'count': 2},
#  {'_id': 'Newton', 'count': 2},
#  {'_id': 'New Haven', 'count': 2},
#  {'_id': 'Port Chester', 'count': 2},
#  {'_id': 'Chicago Heights', 'count': 2},
#  {'_id': 'Austin', 'count': 2},
#  {'_id': 'Perth Amboy', 'count': 2},
#  {'_id': 'Louisville', 'count': 2},
#  {'_id': 'Salt Lake City', 'count': 2},
#  {'_id': 'Tennessee', 'count': 2},
#  {'_id': 'Galveston', 'count': 2},
#  {'_id': 'Zagreb', 'count': 2},
#  {'_id': 'Worcester', 'count': 2},
#  {'_id': 'Milan', 'count': 2},
#  {'_id': 'The Bronx', 'count': 2},
#  {'_id': 'Geneva', 'count': 2},
#  {'_id': 'Athens', 'count': 2},
#  {'_id': 'Council Bluffs', 'count': 2},
#  {'_id': 'Aarhus', 'count': 2},
#  {'_id': 'Vicksburg', 'count': 2},
#  {'_id': 'Norwalk', 'count': 2},
#  {'_id': 'Cambridge', 'count': 2},
#  {'_id': 'Rocky Mount', 'count': 2},
#  {'_id': 'Windsor', 'count': 2},
#  {'_id': 'Des Moines', 'count': 2},
#  {'_id': 'New Brunswick', 'count': 2},
#  {'_id': 'Brussels', 'count': 2},
#  {'_id': 'Pontiac', 'count': 2},
#  {'_id': 'Trinidad', 'count': 2},
#  {'_id': 'Hackensack', 'count': 2},
#  {'_id': 'Paterson', 'count': 2},
#  {'_id': 'Pasadena', 'count': 2},
#  {'_id': 'Panama City', 'count': 2},
#  {'_id': 'Missouri', 'count': 2},
#  {'_id': 'Texas', 'count': 2},
#  {'_id': 'Montgomery', 'count': 2},
#  {'_id': 'Hartford', 'count': 2},
#  {'_id': 'Asheville', 'count': 2},
#  {'_id': 'California', 'count': 1},
#  {'_id': 'Elgin', 'count': 1},
#  {'_id': 'Albany', 'count': 1},
#  {'_id': 'Arlington', 'count': 1},
#  {'_id': 'Olive', 'count': 1},
#  {'_id': 'Ajido', 'count': 1},
#  {'_id': 'Liège', 'count': 1},
#  {'_id': 'Simmesport', 'count': 1},
#  {'_id': 'Ossining', 'count': 1},
#  {'_id': 'Burbank', 'count': 1},
#  {'_id': 'Chelsea', 'count': 1},
#  {'_id': 'Indianola', 'count': 1},
#  {'_id': "Mykolaïvs'ka Oblast'", 'count': 1},
#  {'_id': 'Eastman', 'count': 1},
#  {'_id': 'Trieste', 'count': 1},
#  {'_id': 'Colón', 'count': 1},
#  {'_id': 'Lancaster', 'count': 1},
#  {'_id': 'Tuscaloosa', 'count': 1},
#  {'_id': 'Great Barrington', 'count': 1},
#  {'_id': 'Tyler', 'count': 1},
#  {'_id': 'Saint Croix', 'count': 1},
#  {'_id': 'Long Beach', 'count': 1},
#  {'_id': 'Valparaiso', 'count': 1},
#  {'_id': 'Lyon', 'count': 1},
#  {'_id': 'Saint-Denis', 'count': 1},
#  {'_id': 'Smithville', 'count': 1},
#  {'_id': 'East Chicago', 'count': 1},
#  {'_id': 'Gloucester', 'count': 1},
#  {'_id': 'Wiesbaden', 'count': 1},
#  {'_id': 'Fair Lawn', 'count': 1},
#  {'_id': 'East Moline', 'count': 1},
#  {'_id': 'Sherman', 'count': 1},
#  {'_id': 'Corona', 'count': 1},
#  {'_id': 'Duluth', 'count': 1},
#  {'_id': 'Merano', 'count': 1},
#  {'_id': 'Amsterdam', 'count': 1},
#  {'_id': 'Hampton', 'count': 1},
#  {'_id': 'Bergen', 'count': 1},
#  {'_id': 'Stockton', 'count': 1},
#  {'_id': 'Brockton', 'count': 1},
#  {'_id': 'Hollywood', 'count': 1},
#  {'_id': 'Holmes County', 'count': 1},
#  {'_id': 'Spokane', 'count': 1},
#  {'_id': 'Baton Rouge', 'count': 1},
#  {'_id': 'Pocatello', 'count': 1},
#  {'_id': 'Glen Ridge', 'count': 1},
#  {'_id': 'Herminie', 'count': 1},
#  {'_id': 'Samaná', 'count': 1},
#  {'_id': 'Marianna', 'count': 1},
#  {'_id': 'Kingston', 'count': 1},
#  {'_id': 'Yugoslavia', 'count': 1},
#  {'_id': 'Athol', 'count': 1},
#  {'_id': 'Greenwood', 'count': 1},
#  {'_id': 'Cape Town', 'count': 1},
#  {'_id': 'West Haven', 'count': 1},
#  {'_id': 'Burley', 'count': 1},
#  {'_id': 'Lansing', 'count': 1},
#  {'_id': 'Kingston upon Thames', 'count': 1},
#  {'_id': 'Middletown', 'count': 1},
#  {'_id': 'Allentown', 'count': 1},
#  {'_id': 'Hammersmith', 'count': 1},
#  {'_id': 'Mount Vernon', 'count': 1},
#  {'_id': 'Morristown', 'count': 1},
#  {'_id': 'Pest', 'count': 1},
#  {'_id': 'Glen White', 'count': 1},
#  {'_id': 'Johnstown', 'count': 1},
#  {'_id': 'Greensboro', 'count': 1},
#  {'_id': 'Gary', 'count': 1},
#  {'_id': 'Gothenburg', 'count': 1},
#  {'_id': 'Concord', 'count': 1},
#  {'_id': 'Doncaster', 'count': 1},
#  {'_id': 'Waterbury', 'count': 1},
#  {'_id': 'Edgware', 'count': 1},
#  {'_id': 'Badin', 'count': 1},
#  {'_id': 'Leuven', 'count': 1},
#  {'_id': 'Niles', 'count': 1},
#  {'_id': 'Rock Falls', 'count': 1},
#  {'_id': 'Billings', 'count': 1},
#  {'_id': 'Providence', 'count': 1},
#  {'_id': 'Mar del Plata', 'count': 1},
#  {'_id': 'Ohio', 'count': 1},
#  {'_id': 'Rotterdam', 'count': 1},
#  {'_id': 'Waukegan', 'count': 1},
#  {'_id': 'Bandung', 'count': 1},
#  {'_id': 'Bayonne', 'count': 1},
#  {'_id': 'St. Thomas', 'count': 1},
#  {'_id': 'Martin County', 'count': 1},
#  {'_id': 'Pativilca', 'count': 1},
#  {'_id': 'Utsunomiya', 'count': 1},
#  {'_id': 'Sacramento', 'count': 1},
#  {'_id': 'Wolverhampton', 'count': 1},
#  {'_id': 'St. Petersburg', 'count': 1},
#  {'_id': 'Port Huron', 'count': 1},
#  {'_id': 'Haskell', 'count': 1},
#  {'_id': 'Gifu', 'count': 1},
#  {'_id': 'Lerwick', 'count': 1},
#  {'_id': 'Alton', 'count': 1},
#  {'_id': 'Harrisburg', 'count': 1},
#  {'_id': 'Watkins', 'count': 1},
#  {'_id': 'Woonsocket', 'count': 1},
#  {'_id': 'Somerville', 'count': 1},
#  {'_id': 'Sonora', 'count': 1},
#  {'_id': 'Orange', 'count': 1},
#  {'_id': 'Denison', 'count': 1},
#  {'_id': 'Independence', 'count': 1},
#  {'_id': 'Cheltenham', 'count': 1},
#  {'_id': 'Moultrie', 'count': 1},
#  {'_id': 'Mobile', 'count': 1},
#  {'_id': 'Denver', 'count': 1},
#  {'_id': 'Glens Falls', 'count': 1},
#  {'_id': 'Kensington', 'count': 1},
#  {'_id': 'La Grange', 'count': 1},
#  {'_id': 'Wartrace', 'count': 1},
#  {'_id': 'Sheffield', 'count': 1},
#  {'_id': 'Lindau', 'count': 1},
#  {'_id': 'Kinston', 'count': 1},
#  {'_id': 'Medford', 'count': 1},
#  {'_id': 'Walsenburg', 'count': 1},
#  {'_id': 'Paducah', 'count': 1},
#  {'_id': 'Durham', 'count': 1},
#  {'_id': 'Osaka', 'count': 1},
#  {'_id': 'Prairie View', 'count': 1},
#  {'_id': 'Palatka', 'count': 1},
#  {'_id': 'Thurston County', 'count': 1},
#  {'_id': 'Hyères', 'count': 1},
#  {'_id': 'Palermo', 'count': 1},
#  {'_id': 'Armavir', 'count': 1},
#  {'_id': 'Winston-Salem', 'count': 1},
#  {'_id': 'Nogales', 'count': 1},
#  {'_id': 'Oneida', 'count': 1},
#  {'_id': 'Shenandoah', 'count': 1},
#  {'_id': 'Laurinburg', 'count': 1},
#  {'_id': 'Glasgow', 'count': 1},
#  {'_id': 'Bremen', 'count': 1},
#  {'_id': 'Chicopee', 'count': 1},
#  {'_id': 'Yale', 'count': 1},
#  {'_id': 'Ussel', 'count': 1},
#  {'_id': 'Bergen County', 'count': 1},
#  {'_id': 'Weehawken', 'count': 1},
#  {'_id': 'Budapest', 'count': 1},
#  {'_id': 'Hammond', 'count': 1},
#  {'_id': 'Okmulgee', 'count': 1},
#  {'_id': 'Iowa', 'count': 1},
#  {'_id': 'Groningen', 'count': 1},
#  {'_id': 'Jersey Shore', 'count': 1},
#  {'_id': 'Covington', 'count': 1},
#  {'_id': 'Italy', 'count': 1},
#  {'_id': 'Ascension Parish', 'count': 1},
#  {'_id': 'Port Arthur', 'count': 1},
#  {'_id': 'Zanesville', 'count': 1},
#  {'_id': 'Slab Fork', 'count': 1},
#  {'_id': 'Písek', 'count': 1},
#  {'_id': 'Lejre', 'count': 1},
#  {'_id': 'Lucca', 'count': 1},
#  {'_id': 'Haarlem', 'count': 1},
#  {'_id': 'Othello', 'count': 1},
#  {'_id': 'Centralia', 'count': 1},
#  {'_id': 'Istanbul', 'count': 1},
#  {'_id': 'Marshall', 'count': 1},
#  {'_id': 'Kirkland Lake', 'count': 1},
#  {'_id': 'Bedford', 'count': 1},
#  {'_id': 'Gardena', 'count': 1},
#  {'_id': 'Tallahatchie County', 'count': 1},
#  {'_id': 'Hattiesburg', 'count': 1},
#  {'_id': 'Brawley', 'count': 1},
#  {'_id': 'Hillerød', 'count': 1},
#  {'_id': 'Macon', 'count': 1},
#  {'_id': 'Lunenburg', 'count': 1},
#  {'_id': 'Jackson', 'count': 1},
#  {'_id': 'Plovdiv', 'count': 1},
#  {'_id': 'Altoona', 'count': 1},
#  {'_id': 'Sterling', 'count': 1},
#  {'_id': 'Hamlet', 'count': 1},
#  {'_id': 'Brookline', 'count': 1},
#  {'_id': 'Warsaw', 'count': 1},
#  {'_id': 'Mumbai', 'count': 1},
#  {'_id': 'Syracuse', 'count': 1},
#  {'_id': 'Inglewood', 'count': 1},
#  {'_id': 'Beloit', 'count': 1},
#  {'_id': 'Buenos Aires', 'count': 1},
#  {'_id': 'Cheraw', 'count': 1},
#  {'_id': 'Mitcham', 'count': 1},
#  {'_id': 'Russia', 'count': 1},
#  {'_id': 'Staten Island', 'count': 1},
#  {'_id': 'Aroostook County', 'count': 1},
#  {'_id': 'Massachusetts', 'count': 1},
#  {'_id': 'El Reno', 'count': 1},
#  {'_id': 'Shreveport', 'count': 1},
#  {'_id': 'Namur', 'count': 1},
#  {'_id': 'Morrisania', 'count': 1},
#  {'_id': 'East Riding of Yorkshire', 'count': 1},
#  {'_id': 'Sioux Falls', 'count': 1},
#  {'_id': 'Pensacola', 'count': 1},
#  {'_id': 'Muskogee', 'count': 1},
#  {'_id': 'Ramallah', 'count': 1},
#  {'_id': 'Illinois', 'count': 1},
#  {'_id': 'San Diego', 'count': 1},
#  {'_id': 'Logansport', 'count': 1},
#  {'_id': 'Owensboro', 'count': 1},
#  {'_id': 'Elkton', 'count': 1},
#  {'_id': 'Plainfield', 'count': 1},
#  {'_id': 'Algiers', 'count': 1},
#  {'_id': 'Saint-Cloud', 'count': 1},
#  {'_id': 'Pasquotank County', 'count': 1},
#  {'_id': 'Racibórz', 'count': 1},
#  {'_id': 'Napoli', 'count': 1},
#  {'_id': 'Portland', 'count': 1},
#  {'_id': 'Wichita Falls', 'count': 1},
#  {'_id': 'Lymington', 'count': 1},
#  {'_id': 'Brixton', 'count': 1},
#  {'_id': 'Norfolk', 'count': 1},
#  {'_id': 'Fort Wayne', 'count': 1},
#  {'_id': 'Fayetteville', 'count': 1},
#  {'_id': 'Americus', 'count': 1},
#  {'_id': 'Germany', 'count': 1},
#  {'_id': 'Thomson', 'count': 1},
#  {'_id': 'Wolford', 'count': 1},
#  {'_id': 'Leeds', 'count': 1},
#  {'_id': 'Pine Bluff', 'count': 1},
#  {'_id': 'Indiana', 'count': 1},
#  {'_id': 'Honolulu', 'count': 1},
#  {'_id': 'Fort Belvoir', 'count': 1},
#  {'_id': 'Florida', 'count': 1},
#  {'_id': 'Phoenix', 'count': 1},
#  {'_id': 'São Paulo', 'count': 1},
#  {'_id': "St. John's", 'count': 1},
#  {'_id': 'Fort Worth', 'count': 1},
#  {'_id': 'Oklahoma', 'count': 1},
#  {'_id': 'North Yorkshire', 'count': 1},
#  {'_id': 'Florence', 'count': 1},
#  {'_id': 'Frankfurt am Main', 'count': 1},
#  {'_id': 'Trondheim', 'count': 1},
#  {'_id': 'Highland Park', 'count': 1},
#  {'_id': 'Berkeley', 'count': 1},
#  {'_id': 'Salina', 'count': 1},
#  {'_id': 'Trenton', 'count': 1},
#  {'_id': 'Irondequoit', 'count': 1},
#  {'_id': 'Calgary', 'count': 1},
#  {'_id': 'Santa Catarina', 'count': 1},
#  {'_id': 'Lima', 'count': 1},
#  {'_id': 'Ferndale', 'count': 1},
#  {'_id': 'St. Charles County', 'count': 1},
#  {'_id': 'Taunton', 'count': 1},
#  {'_id': 'Söderhamn', 'count': 1},
#  {'_id': 'South Africa', 'count': 1},
#  {'_id': 'Antonito', 'count': 1},
#  {'_id': 'Haverhill', 'count': 1}]
